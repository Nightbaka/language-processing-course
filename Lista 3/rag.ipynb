# %%
import os
import getpass
import requests
import numpy as np
import pandas as pd
from datasets import Dataset
import torch
from transformers import AutoTokenizer, AutoModel
import faiss

# %%
xlsx_path = "tb_chunks.xlsx"
df = pd.read_excel(xlsx_path)

# %% [markdown]
# ### 1.1. Mały klient HTTP do CLARIN

# %%
CLARIN_API_KEY = getpass.getpass("Podaj CLARIN API key (nie będzie wyświetlany): ")

if not CLARIN_API_KEY:
    raise ValueError("Nie podano CLARIN_API_KEY")

os.environ["CLARIN_API_KEY"] = CLARIN_API_KEY

# %%
CLARIN_BASE_URL = "https://services.clarin-pl.eu/api/v1/oapi"
CLARIN_API_KEY = os.environ.get("CLARIN_API_KEY")  
if CLARIN_API_KEY is None:
    raise ValueError("Ustaw zmienną środowiskową CLARIN_API_KEY z tokenem z WebServices CLARIN-PL.")

HEADERS = {
    "Authorization": f"Bearer {CLARIN_API_KEY}",
    "Content-Type": "application/json",
}

# %% [markdown]
# ### 1.2. Lista modeli – /api/v1/oapi/models

# %%
def clarin_list_models():
    url = f"{CLARIN_BASE_URL}/models"
    resp = requests.get(url, headers=HEADERS)
    resp.raise_for_status()
    data = resp.json()
    return data

models = clarin_list_models()
print(models)
# Out:
# {'data': [{'id': 'bielik', 'full_name': 'speakleash/Bielik-11B-v2.2-Instruct', 'name': 'speakleash/Bielik-11B-v2.2-Instruct', 'type': 'chat'}, {'id': 'c4ai-command-a', 'full_name': 'CohereForAI/c4ai-command-a-03-2025', 'name': 'CohereForAI/c4ai-command-a-03-2025', 'type': 'chat'}, {'id': 'cohere', 'full_name': 'CohereForAI/c4ai-command-r-plus', 'name': 'CohereForAI/c4ai-command-r-plus', 'type': 'chat'}, {'id': 'gemma-3-4b-it', 'full_name': 'google/gemma-3-4b-it', 'name': 'google/gemma-3-4b-it', 'type': 'chat'}, {'id': 'dariah-eventstotriples', 'full_name': 'dariah/pllum12b-01_10', 'name': 'dariah/pllum12b-01_10', 'type': 'chat'}, {'id': 'clarin-affect-pllum', 'full_name': 'dariah/clarin-affect-pllum-autoregressive', 'name': 'dariah/clarin-affect-pllum-autoregressive', 'type': 'chat'}, {'id': 'llama3.1', 'full_name': 'meta-llama/Meta-Llama-3.1-70B-Instruct', 'name': 'meta-llama/Meta-Llama-3.1-70B-Instruct', 'type': 'chat'}, {'id': 'llama-guard', 'full_name': 'meta-llama/Llama-Guard-3-8B', 'name': 'meta-llama/Llama-Guard-3-8B', 'type': 'chat'}, {'id': 'llama-4-scout-17b', 'full_name': 'meta-llama/Llama-4-Scout-17B-16E-Instruct', 'name': 'meta-llama/Llama-4-Scout-17B-16E-Instruct', 'type': 'chat'}, {'id': 'llama3.3', 'full_name': 'meta-llama/Llama-3.3-70B-Instruct', 'name': 'meta-llama/Llama-3.3-70B-Instruct', 'type': 'chat'}, {'id': 'openchat', 'full_name': 'openchat/openchat-3.5-1210', 'name': 'openchat/openchat-3.5-1210', 'type': 'chat'}, {'id': 'mixtral-8x22B', 'full_name': 'mistralai/Mixtral-8x22B-Instruct-v0.1', 'name': 'mistralai/Mixtral-8x22B-Instruct-v0.1', 'type': 'chat'}, {'id': 'medgemma-4b-it', 'full_name': '', 'name': '', 'type': 'chat'}, {'id': 'llama3.1-8b', 'full_name': 'meta-llama/Llama-3.1-8B-Instruct', 'name': 'meta-llama/Llama-3.1-8B-Instruct', 'type': 'chat'}, {'id': 'clarin_functionengine', 'full_name': 'clarin_functionengine', 'name': 'clarin_functionengine', 'type': 'chat'}, {'id': 'llama-8b-base-pos-tagger', 'full_name': 'pllum/llama-8b-base-pos-tagger', 'name': 'pllum/llama-8b-base-pos-tagger', 'type': 'chat'}, {'id': 'llama', 'full_name': 'meta-llama/Llama-3.1-8B-Instruct', 'name': 'meta-llama/Llama-3.1-8B-Instruct', 'type': 'chat'}]}

# %%
CLARIN_MODEL_NAME = "llama3.1"

# %% [markdown]
# Komentarz do wyboru Meta Llamy 3.1 70B Instruct: Najlepsze EN, najlepszy reasoning, najmniej halucynacji, idealny do RAG i raportów

# %% [markdown]
# ### 1.3. Chat completions – /api/v1/oapi/chat/completions

# %%
def clarin_chat(messages, model: str = CLARIN_MODEL_NAME,
                temperature: float = 0.1,
                max_tokens: int = 1024) -> str:
    """
    messages: lista słowników {"role": "system"|"user"|"assistant", "content": "..."}
    """
    url = f"{CLARIN_BASE_URL}/chat/completions"
    payload = {
        "model": model,
        "messages": messages,
        "temperature": temperature,
        "max_tokens": max_tokens,
    }
    resp = requests.post(url, headers=HEADERS, json=payload)
    resp.raise_for_status()
    data = resp.json()
    # zgodnie z konwencją OpenAI
    return data["choices"][0]["message"]["content"]

# %%
test_messages = [
    {"role": "system", "content": "Jesteś asystentem, odpowiadasz krótko po polsku."},
    {"role": "user", "content": "Wyjaśnij w jednym zdaniu co to jest RAG (Retrievial Augmented Generation)."},
]
print(clarin_chat(test_messages))
# Out:
# RAG (Retrieval-Augmented Generation) to model językowy, który łączy mechanizmy wyszukiwania i generowania tekstu, aby poprawić jakość i dokładność wygenerowanego tekstu.

# %% [markdown]
# ### 2. Krok 2 – ładujemy modele embeddingowe i używamy naszego indeksu regulacji jako retrievera

# %%
model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = AutoModel.from_pretrained(model_ckpt)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# MPNetModel(
#   (embeddings): MPNetEmbeddings(
#     (word_embeddings): Embedding(30527, 768, padding_idx=1)
#     (position_embeddings): Embedding(514, 768, padding_idx=1)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): MPNetEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (relative_attention_bias): Embedding(32, 12)
#   )
#   (pooler): MPNetPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
TEXT_COL =  "text"

embeddings_ds = Dataset.load_from_disk("regs_chunks_with_embeddings")

all_embs = np.vstack(embeddings_ds["embeddings"]).astype("float32")
num_docs, emb_dim = all_embs.shape
print(num_docs, emb_dim)

faiss_index = faiss.IndexFlatIP(emb_dim)
faiss_index.add(all_embs)
# Out:
# 2836 768

# %% [markdown]
# ### 2.1. Funkcja: semantic search -> top_k chunków

# %%
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]

# %%
def embed_query(query: str) -> np.ndarray:
    
    encoded = tokenizer(
        [query],
        padding=True,
        truncation=True,
        max_length=512,
        return_tensors="pt",
    ).to(device)
    with torch.no_grad():
        output = model(**encoded)
        q_emb = cls_pooling(output)  # ta sama jak wcześniej
        q_emb = torch.nn.functional.normalize(q_emb, p=2, dim=1)
    return q_emb.cpu().numpy().astype("float32")  # (1, dim)


def retrieve_contexts_local(query: str, top_k: int = 8) -> list[dict]:
    q_emb = embed_query(query)      # (1, d)
    scores, idx = faiss_index.search(q_emb, top_k)   # idx: (1, k)
    scores = scores[0]
    idx = idx[0]

    rows = df.iloc[idx].copy()
    rows["score"] = scores

    contexts = []
    for _, row in rows.iterrows():
        contexts.append({
            "text": str(row[TEXT_COL]),
            "anchor": row.get("anchor"),
            "doc_id": row.get("doc_id"),
            "reg_no": row.get("reg_no"),
            "section_path": row.get("section_path"),
            "annex_id": row.get("annex_id"),
        })
    return contexts

# %% [markdown]
# ### 3. Krok 3 – moduł generacji (RAG) z CLARIN

# %%
REPORT_SYSTEM_PROMPT = """
You are a senior homologation / regulatory engineer helping non-technical readers.

You receive:
- A description of a software or logic change in a vehicle system or function
  (for example: lighting, braking, ADAS, HMI, cybersecurity, diagnostics, etc.).
- Several passages from UN/EU automotive regulations (e.g. UNECE R48, R13, R79, R156, ...).

Your tasks:
1) Use ONLY the provided regulation passages as your legal source.
2) Produce a short, readable report in clear English, for non-technical people.
3) Always include explicit clause references (e.g. “UNECE R48 §6.5.8”) with citations.
4) If something is not covered by the context, clearly say “Not covered in the provided regulations”.

Output format (markdown):

# Regulatory impact report - {short_title}

## 1. Change summary
- 2-4 bullet points that restate the change in simple terms.

## 2. Potentially impacted functions
- Brief bullets: which vehicle functions / ECUs are affected
  (based ONLY on the change description and context).
- Explain in very simple terms what they do.

## 3. Applicable regulations and clauses
Create a small bullet list or table. For each relevant clause:
- Regulation and clause (e.g. "UNECE R48 §6.5.8").
- One-line explanation of what it requires.
- Why it is relevant to this change.

## 4. Compliance assessment for this change
For each clause from section 3, classify:
- Status: one of {PASS, POSSIBLE IMPACT - REVIEW, OUT OF SCOPE}.
- Short rationale in plain language, grounded in the context passages.
- If context is unclear or missing, mark POSSIBLE IMPACT - REVIEW and say what needs to be checked.

## 5. Suggested test plan & documentation
- 4-6 bullet points with high-level tests or checks
  (e.g. timing, behaviors in edge cases, malfunction warnings, traceability).
- Reference the relevant clauses when possible.
- Keep it non-technical (what needs to be checked, not how to code it).

Rules:
- Do not invent regulation text; stay within the given context.
- If multiple documents disagree, briefly mention the uncertainty.
- Keep wording short and business-oriented, not academic.
"""

# %% [markdown]
# ### 3.2. Budowa promptu użytkownika (change + context)

# %%
import textwrap

def build_user_prompt_report(change_description: str,
                             context_chunks: list[dict]) -> str:
    ctx_lines = []
    for i, c in enumerate(context_chunks, 1):
        snippet = c["text"].replace("\n\n", "\n").strip()
        snippet = textwrap.shorten(snippet, width=1400, placeholder=" …")

        anchor = c.get("anchor")
        if not anchor:
            anchor = f"{c.get('reg_no', 'Regulation')} {c.get('section_path') or c.get('annex_id') or ''}".strip()

        ctx_lines.append(
            f"### [{i}] {anchor}\n"
            f"Source: {c.get('doc_id')}\n"
            f"{snippet}\n"
        )

    ctx_block = "\n\n".join(ctx_lines)

    user_msg = f"""
You are assessing one specific software / logic change.

Change description:
\"\"\"{change_description}\"\"\"

Below are the most relevant regulation excerpts:

{ctx_block}

Using ONLY these passages, write the report in the requested format.
If you are unsure, mark the item as REVIEW and explain what needs human validation.
"""
    return user_msg.strip()

# %% [markdown]
# ### 3.3. Funkcja RAG: retrieval → CLARIN → odpowiedź

# %%
def run_regulatory_report_clarin(change_description: str,
                                 top_k: int = 8) -> str:
    # 1) retrieval
    contexts = retrieve_contexts_local(change_description, top_k=top_k)
    if not contexts:
        return "No relevant regulation passages were found in the index."

    # 2) budowa promptu
    user_prompt = build_user_prompt_report(change_description, contexts)
    short_title = change_description.strip().replace("\n", " ")[:80]

    # 3) wywołanie CLARIN chat completion
    messages = [
        {"role": "system", "content": REPORT_SYSTEM_PROMPT},
        {"role": "system", "content": f"Short title for the report: {short_title}"},
        {"role": "user", "content": user_prompt},
    ]
    answer = clarin_chat(messages, model=CLARIN_MODEL_NAME, temperature=0.2, max_tokens=2000)
    return answer

# %% [markdown]
# ### 4. Przykładowe zapytania (use-case zmiany w softwarze)

# %%
change1 = """
LIGHT LEFT TURN.V2 - change from version R11 to R12:
- Turn indicator status signals changed from .Req to .Info
- Updated diagnostics and fallback if ETH_L_TurnCluster.Info is missing
- Revised animation when mirror turn signal shares light guide with position lamp
"""

change2 = """
Low Beam / High Beam logic
- Updated LB/HB requirements with new fallback conditions
- Modified high-beam signal mapping
- Clarified simultaneous LB+HB activation feasibility
"""

change3 = """
Direction indicator tell-tale behavior changed: visual indicator now flashes at a constant rate, 
even when one trailer indicator lamp fails.
"""

for ch in [change1, change2, change3]:
    print("="*80)
    print("CHANGE:\n", ch)
    print("\nRAG ANSWER (CLARIN):\n")
    print(run_regulatory_report_clarin(ch, top_k=8))
    print("\n\n")
# Out:
# ================================================================================
# CHANGE:
#
# LIGHT LEFT TURN.V2 - change from version R11 to R12:
# - Turn indicator status signals changed from .Req to .Info
# - Updated diagnostics and fallback if ETH_L_TurnCluster.Info is missing
# - Revised animation when mirror turn signal shares light guide with position lamp
#
#
# RAG ANSWER (CLARIN):
#
# # Regulatory Impact Report - LIGHT LEFT TURN.V2
#
# ## 1. Change Summary
# * The turn indicator status signals have been updated from ".Req" to ".Info".
# * Diagnostics and fallback behavior have been modified in case the ETH_L_TurnCluster.Info signal is missing.
# * Animation has been revised when the mirror turn signal shares a light guide with the position lamp.
#
# ## 2. Potentially Impacted Functions
# * Turn indicator lamps: These lamps indicate the intention of the driver to change direction or lanes.
# * Hazard warning lights: These lights alert other road users to potential hazards.
# * Position lamps: These lamps provide visibility to the vehicle's presence and dimensions.
#
# ## 3. Applicable Regulations and Clauses
# | Regulation | Clause | Requirement | Relevance |
# | --- | --- | --- | --- |
# | UN R48 | §5.9.1 | Direction-indicator lamps must be flashing lamps. | Relevant due to changes in turn indicator status signals. |
# | UN R79 | §2.4.16 | Defines a Lane Change Procedure, including activation and deactivation of direction indicator lamps. | Relevant due to changes in turn indicator status signals. |
# | UN R79 | §5.1.6.3.9.14 | Requires timely deactivation of direction indicator lamps after completing a lane change maneuver. | Relevant due to changes in turn indicator status signals. |
#
# ## 4. Compliance Assessment for this Change
# | Regulation | Clause | Status | Rationale |
# | --- | --- | --- | --- |
# | UN R48 | §5.9.1 | PASS | The change does not affect the flashing functionality of the direction-indicator lamps. |
# | UN R79 | §2.4.16 | POSSIBLE IMPACT - REVIEW | Needs review to confirm that the updated turn indicator status signals comply with the defined Lane Change Procedure. |
# | UN R79 | §5.1.6.3.9.14 | POSSIBLE IMPACT - REVIEW | Needs review to confirm that the direction indicator lamps are deactivated in a timely manner after completing a lane change maneuver. |
#
# ## 5. Suggested Test Plan & Documentation
# * Verify that the turn indicator lamps flash correctly after the update (UN R48 §5.9.1).
# * Validate that the Lane Change Procedure is followed correctly, including activation and deactivation of direction indicator lamps (UN R79 §2.4.16).
# * Check that the direction indicator lamps are deactivated in a timely manner after completing a lane change maneuver (UN R79 §5.1.6.3.9.14).
# * Confirm that the hazard warning lights become active again after the lane change maneuver is completed (UN R79 §5.1.6.3.9.14).
# * Review the diagnostics and fallback behavior in case the ETH_L_TurnCluster.Info signal is missing.
# * Inspect the revised animation when the mirror turn signal shares a light guide with the position lamp.
#
#
#
# ================================================================================
# CHANGE:
#
# Low Beam / High Beam logic
# - Updated LB/HB requirements with new fallback conditions
# - Modified high-beam signal mapping
# - Clarified simultaneous LB+HB activation feasibility
#
#
# RAG ANSWER (CLARIN):
#
# # Regulatory Impact Report - Low Beam / High Beam Logic Update
#
# ## 1. Change Summary
# * The low beam/high beam logic has been updated with new fallback conditions.
# * The high-beam signal mapping has been modified.
# * The possibility of simultaneous low beam and high beam activation has been clarified.
#
# ## 2. Potentially Impacted Functions
# * Headlamp control unit (ECU): This is the electronic control unit responsible for controlling the headlights, including switching between low beam and high beam.
# * Sensor systems: These are used to detect ambient lighting conditions, oncoming vehicles, and other factors that influence the decision to switch between low beam and high beam.
#
# ## 3. Applicable Regulations and Clauses
# | Regulation and Clause | Requirement | Relevance |
# | --- | --- | --- |
# | UNECE R48 §6.2.7.1 | Main beams must be switched off simultaneously when changing from main beam to dipped beam. | Ensures safe and coordinated switching between low beam and high beam. |
# | UNECE R48 §6.2.7.2 | Dipped beam may remain switched on at the same time as main beam. | Allows for simultaneous activation of low beam and high beam under certain conditions. |
# | UNECE R48 §6.22.7.1.2 | Adaptive main beam may be designed to react to various inputs, including ambient lighting conditions and oncoming vehicles. | Relevant to the modification of high-beam signal mapping and the use of sensor systems. |
#
# ## 4. Compliance Assessment for this Change
# | Regulation and Clause | Status | Rationale |
# | --- | --- | --- |
# | UNECE R48 §6.2.7.1 | PASS | The update does not affect the simultaneous switching off of main beams. |
# | UNECE R48 §6.2.7.2 | POSSIBLE IMPACT - REVIEW | The clarification of simultaneous low beam and high beam activation feasibility may require verification that the dipped beam remains switched on correctly. |
# | UNECE R48 §6.22.7.1.2 | POSSIBLE IMPACT - REVIEW | The modification of high-beam signal mapping and the use of sensor systems may need to be verified against the regulation's requirements for adaptive main beam design. |
#
# ## 5. Suggested Test Plan & Documentation
# * Verify that main beams switch off simultaneously when changing from main beam to dipped beam (UNECE R48 §6.2.7.1).
# * Test the simultaneous activation of low beam and high beam under various conditions to ensure correct behavior (UNECE R48 §6.2.7.2).
# * Validate the modification of high-beam signal mapping against the regulation's requirements for adaptive main beam design (UNECE R48 §6.22.7.1.2).
# * Check the functionality of sensor systems in detecting ambient lighting conditions and oncoming vehicles.
# * Review the test drive specifications for the automatic control of main-beam headlamps (UNECE R48 Annex 12).
#
#
#
# ================================================================================
# CHANGE:
#
# Direction indicator tell-tale behavior changed: visual indicator now flashes at a constant rate,
# even when one trailer indicator lamp fails.
#
#
# RAG ANSWER (CLARIN):
#
# # Regulatory Impact Report - Direction Indicator Tell-Tale Behavior Changed
#
# ## 1. Change Summary
# * The direction indicator tell-tale's behavior has been modified to flash at a constant rate even if one trailer indicator lamp fails.
# * This means the tell-tale will no longer indicate a fault through a change in frequency.
# * The change only affects the visual aspect of the tell-tale.
# * The functionality of the direction indicators themselves remains unchanged.
#
# ## 2. Potentially Impacted Functions
# * Direction indicator lamps (front and rear): These are the lights on the vehicle that indicate the driver's intention to turn left or right.
# * Trailer indicator lamps: These are the lights on a trailer that indicate the driver's intention to turn left or right when towing a trailer.
# * Visual tell-tale for direction indicators: This is an indicator inside the vehicle that shows the status of the direction indicators (e.g., flashing or steady light).
#
# ## 3. Applicable Regulations and Clauses
# | Regulation | Clause | Requirement | Relevance |
# | --- | --- | --- | --- |
# | UNECE R48 | §6.5.9 | In the event of failure of one direction-indicator lamp, the others shall continue to flash, but the frequency in this condition may be different from that prescribed. | Relevant because the change involves the behavior of the tell-tale when a trailer indicator lamp fails. |
# | UNECE R48 | §6.5.8 | If it is visual, the tell-tale shall show a marked change of frequency, at least in the event of the malfunction of any of these direction-indicator lamps. | Directly relevant to the change, as it specifies the required behavior of the visual tell-tale upon malfunction. |
#
# ## 4. Compliance Assessment for this Change
# | Regulation | Clause | Status | Rationale |
# | --- | --- | --- | --- |
# | UNECE R48 | §6.5.9 | PASS | The regulation allows for a different frequency in the event of a failure, which implies that maintaining a constant rate could be acceptable. However, careful review is needed to ensure compliance. |
# | UNECE R48 | §6.5.8 | POSSIBLE IMPACT - REVIEW | The change appears to contradict the requirement for a marked change in frequency upon malfunction. Further review is necessary to assess compliance and potential implications. |
#
# ## 5. Suggested Test Plan & Documentation
# * Verify that the direction indicator tell-tale continues to flash at a constant rate when one trailer indicator lamp fails (UNECE R48 §6.5.9).
# * Check that the tell-tale's behavior meets the requirements for a marked change of frequency upon malfunction (UNECE R48 §6.5.8). This might involve reviewing the design specifications and testing under various conditions.
# * Confirm that the direction indicators themselves function correctly despite the change in tell-tale behavior.
# * Document the testing process and results, including any deviations from expected outcomes.
# * Review and validate the compliance of the new tell-tale behavior against UNECE R48 §6.5.8, considering the possibility of seeking clarification or exemption if necessary.
